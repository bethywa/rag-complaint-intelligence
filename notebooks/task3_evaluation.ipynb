# %%
import sys
from pathlib import Path

# Add project root to PYTHONPATH
project_root = Path().resolve().parents[0]
sys.path.append(str(project_root))

print("Added to path:", project_root)
# Out:
# Added to path: D:\10acadamyWeek7 project\rag-complaint-intelligence

# %%
from src.pipeline import run_pipeline
# Out:
# Device set to use cpu

# %%
questions = [
    "What are common complaints related to billing errors on credit cards?",
    "Which companies had account closures?",
    "Are banks resolving credit card fraud complaints effectively?",
    "What problems do customers face with chargebacks and refunds?",
    "Which companies receive the most complaints related to credit cards?"
]

# %%
results = []

for q in questions:
    answer, sources = run_pipeline(q)
    results.append({
        "Question": q,
        "Generated Answer": answer,
        "Retrieved Sources": sources[:2]  # show only 1–2
    })

# %%
evaluation = [
    {
        "Question": results[0]["Question"],
        "Generated Answer": results[0]["Generated Answer"],
        "Retrieved Sources": results[0]["Retrieved Sources"],
        "Quality Score (1–5)": 4,
        "Comments / Analysis": "Answer accurately summarizes recurring billing issues from retrieved complaints."
    },
    {
        "Question": results[1]["Question"],
        "Generated Answer": results[1]["Generated Answer"],
        "Retrieved Sources": results[1]["Retrieved Sources"],
        "Quality Score (1–5)": 4,
        "Comments / Analysis": "Correctly identifies companies involved in account closures, but lacks explanation of reasons."
    },
    {
        "Question": results[2]["Question"],
        "Generated Answer": results[2]["Generated Answer"],
        "Retrieved Sources": results[2]["Retrieved Sources"],
        "Quality Score (1–5)": 3,
        "Comments / Analysis": "Relevant context retrieved, but answer is based on limited evidence."
    },
    {
        "Question": results[3]["Question"],
        "Generated Answer": results[3]["Generated Answer"],
        "Retrieved Sources": results[3]["Retrieved Sources"],
        "Quality Score (1–5)": 2,
        "Comments / Analysis": "System correctly avoided hallucination, but retrieval lacked sufficient chargeback data."
    },
    {
        "Question": results[4]["Question"],
        "Generated Answer": results[4]["Generated Answer"],
        "Retrieved Sources": results[4]["Retrieved Sources"],
        "Quality Score (1–5)": 3,
        "Comments / Analysis": "Identifies a major company, but aggregation across multiple companies is missing."
    }
]

evaluation
# Out:
# [{'Question': 'What are common complaints related to billing errors on credit cards?',
#   'Generated Answer': '1 failure to credit my account properly, 2 failure to mail my statement to my current address resulting in no billing statements for three months, 3 failure to provide additional information regarding my current balance, and 4 failure to validate the debt reflected in the past due balance',
#   'Retrieved Sources': [{'text': 'billing errors, which include inaccuracies in payment reporting.',
#     'metadata': {'chunk_index': 1,
#      'company': 'DISCOVER BANK',
#      'complaint_id': '11293797',
#      'date_received': '2024-12-28',
#      'issue': 'Problem when making payments',
#      'product': 'Credit card',
#      'product_category': 'Credit Card',
#      'state': 'DE',
#      'sub_issue': 'You never received your bill or did not know a payment was due',
#      'total_chunks': 2}},
#    {'text': 'billing errors, which include inaccuracies in payment reporting.',
#     'metadata': {'chunk_index': 1,
#      'company': 'WELLS FARGO & COMPANY',
#      'complaint_id': '11561050',
#      'date_received': '2025-01-17',
#      'issue': 'Problem when making payments',
#      'product': 'Credit card',
#      'product_category': 'Credit Card',
#      'state': 'CA',
#      'sub_issue': 'You never received your bill or did not know a payment was due',
#      'total_chunks': 2}}],
#   'Quality Score (1–5)': 4,
#   'Comments / Analysis': 'Answer accurately summarizes recurring billing issues from retrieved complaints.'},
#  {'Question': 'Which companies had account closures?',
#   'Generated Answer': 'CITIBANK, N.A. --- Company: WELLS FARGO & COMPANY Complaint: closure of all current accounts and has also caused cancellation of all previous accounts a number of years ago as well. --- Company: CAPITAL ONE FINANCIAL CORPORATION Complaint: closure of all current accounts and has also caused cancellation of all previous accounts a number of years ago as well. --- Company: CITIBANK, N.A. Complaint: account balances were promptly paid within terms. p additionally, back in , citibank closed my personal checking account, a business savings account and two business checking accounts. they refused to provide me with any reason for the account closings. these accounts had be active and open for over 15 years. all of these accounts were in good standing. my business is a reputable company, , and we have been in business since --- Company: JPMORGAN CHASE & CO. Complaint: orithms of banks like jp morgan chase bank , leading to unjustified closures of customers account. thank you',
#   'Retrieved Sources': [{'text': 'closure of all current accounts and has also caused cancellation of all previous accounts a number of years ago as well.',
#     'metadata': {'chunk_index': 2,
#      'company': 'CAPITAL ONE FINANCIAL CORPORATION',
#      'complaint_id': '11223556',
#      'date_received': '2024-12-19',
#      'issue': 'Trouble using your card',
#      'product': 'Credit card',
#      'product_category': 'Credit Card',
#      'state': 'NY',
#      'sub_issue': "Can't use card to make purchases",
#      'total_chunks': 3}},
#    {'text': "lost and events unfolding still today as we speak. being an investor once with accounts were suddenly closed for no reason given. passed thru and account was closed 10 minutes after the transaction with the reason security risk '' with no following communication by the company. all these companies are tied together and have been sticking it to the consumer this entire time and brushing off the warnings and or reports by the consumer.",
#     'metadata': {'chunk_index': 1,
#      'company': 'Block, Inc.',
#      'complaint_id': '9776162',
#      'date_received': '2024-08-12',
#      'issue': 'Fraud or scam',
#      'product': 'Money transfer, virtual currency, or money service',
#      'product_category': 'Money Transfer',
#      'state': 'NV',
#      'sub_issue': 'nan',
#      'total_chunks': 4}}],
#   'Quality Score (1–5)': 4,
#   'Comments / Analysis': 'Correctly identifies companies involved in account closures, but lacks explanation of reasons.'},
#  {'Question': 'Are banks resolving credit card fraud complaints effectively?',
#   'Generated Answer': 'a few weeks later, i received an email stating that the claim for all 3 transactions was denied due to the charges being from a micro-chip enabled terminal. i contacted claims and asked for an explanation they stated my card was used and i can not dispute the card use. --- Company: CAPITAL ONE FINANCIAL CORPORATION Complaint: y other bank as well, which has given me no issue. i set up an appointment with the bank fraud detectives at and filed a police report providing the cards, the statements, and the claims info for banks. a few weeks later, i received an email stating that the claim for all 3 transactions was denied due to the charges being from a micro-chip enabled terminal. i contacted claims and asked for an explanation they stated my card was used and i can not dispute the card use. --- Company: U.S. BANCORP Complaint: i am submitting a complaint against u.s. bank regarding a denied fraud claim related to unauthorized debit card transactions. i reported three fraudulent charges totaling 500.00 , which occurred between and year ,',
#   'Retrieved Sources': [{'text': 'y other bank as well, which has given me no issue. i set up an appointment with the bank fraud detectives at and filed a police report providing the cards, the statements, and the claims info for banks. a few weeks later, i received an email stating that the claim for all 3 transactions was denied due to the charges being from a micro-chip enabled terminal. i contacted claims and asked for an explanation they stated my card was used and i can not dispute the card use.',
#     'metadata': {'chunk_index': 2,
#      'company': 'CAPITAL ONE FINANCIAL CORPORATION',
#      'complaint_id': '6638126',
#      'date_received': '2023-03-02',
#      'issue': 'Managing an account',
#      'product': 'Checking or savings account',
#      'product_category': 'Savings Account',
#      'state': 'CA',
#      'sub_issue': 'Problem using a debit or ATM card',
#      'total_chunks': 9}},
#    {'text': "far in order to catch their attention to my concerns. this really doesn't show their complaints department in a good light, to say the least and certainly, does not contribute tomyoverall satisfaction and peace of mind. my complaint is against the bank that did not do its job properly could not prevent foreseen fraud and could not conduct a proper investigation and not against the vulnerable customer who fell victim and lost all the savings due to the misconduct of the bank.",
#     'metadata': {'chunk_index': 1,
#      'company': 'BANK OF AMERICA, NATIONAL ASSOCIATION',
#      'complaint_id': '6736230',
#      'date_received': '2023-03-22',
#      'issue': 'Other transaction problem',
#      'product': 'Money transfer, virtual currency, or money service',
#      'product_category': 'Money Transfer',
#      'state': 'FL',
#      'sub_issue': 'nan',
#      'total_chunks': 72}}],
#   'Quality Score (1–5)': 3,
#   'Comments / Analysis': 'Relevant context retrieved, but answer is based on limited evidence.'},
#  {'Question': 'What problems do customers face with chargebacks and refunds?',
#   'Generated Answer': "I don't have enough information in the provided context to answer this question.",
#   'Retrieved Sources': [{'text': 'issues or chargebacks.',
#     'metadata': {'chunk_index': 2,
#      'company': 'Paypal Holdings, Inc',
#      'complaint_id': '7242686',
#      'date_received': '2023-07-12',
#      'issue': 'Managing, opening, or closing your mobile wallet account',
#      'product': 'Money transfer, virtual currency, or money service',
#      'product_category': 'Money Transfer',
#      'state': 'PA',
#      'sub_issue': 'nan',
#      'total_chunks': 3}},
#    {'text': 'nitiating chargebacks on honest, small businesses. this makes the credit card company look great to customers, but they are really just stealing money form small businesses. for instance a customer received my product and installed it incorrectly, resulting in a broken piece. we offered to send her a replacement at no cost. she contacted her credit card company without offering to return the item. the credit card company initiated a chargeback, and the customer still has our item.',
#     'metadata': {'chunk_index': 1,
#      'company': 'AMERICAN EXPRESS COMPANY',
#      'complaint_id': '6748018',
#      'date_received': '2023-03-25',
#      'issue': 'Other features, terms, or problems',
#      'product': 'Credit card or prepaid card',
#      'product_category': 'Credit Card',
#      'state': 'CA',
#      'sub_issue': 'Other problem',
#      'total_chunks': 7}}],
#   'Quality Score (1–5)': 2,
#   'Comments / Analysis': 'System correctly avoided hallucination, but retrieval lacked sufficient chargeback data.'},
#  {'Question': 'Which companies receive the most complaints related to credit cards?',
#   'Generated Answer': 'AMERICAN EXPRESS COMPANY',
#   'Retrieved Sources': [{'text': 'card companies and the credit bureaus.',
#     'metadata': {'chunk_index': 3,
#      'company': 'AMERICAN EXPRESS COMPANY',
#      'complaint_id': '6215360',
#      'date_received': '2022-11-18',
#      'issue': 'Other features, terms, or problems',
#      'product': 'Credit card or prepaid card',
#      'product_category': 'Credit Card',
#      'state': 'FL',
#      'sub_issue': 'Other problem',
#      'total_chunks': 4}},
#    {'text': 'any. i am sure that you had many other complaints. i would like to get my money back and hope you will restrict them from operating a credit card scam.',
#     'metadata': {'chunk_index': 2,
#      'company': 'Self Financial Inc.',
#      'complaint_id': '6604272',
#      'date_received': '2023-02-22',
#      'issue': 'Closing your account',
#      'product': 'Credit card or prepaid card',
#      'product_category': 'Credit Card',
#      'state': 'VA',
#      'sub_issue': "Can't close your account",
#      'total_chunks': 3}}],
#   'Quality Score (1–5)': 3,
#   'Comments / Analysis': 'Identifies a major company, but aggregation across multiple companies is missing.'}]

# %%
import pandas as pd

df_eval = pd.DataFrame(evaluation)
df_eval
# Out:
#                                             Question  \
# 0  What are common complaints related to billing ...
# 1              Which companies had account closures?
# 2  Are banks resolving credit card fraud complain...
# 3  What problems do customers face with chargebac...
# 4  Which companies receive the most complaints re...
#
#                                     Generated Answer  \
# 0  1 failure to credit my account properly, 2 fai...
# 1  CITIBANK, N.A. --- Company: WELLS FARGO & COMP...
# 2  a few weeks later, i received an email stating...
# 3  I don't have enough information in the provide...
# 4                           AMERICAN EXPRESS COMPANY
#
#                                    Retrieved Sources  Quality Score (1–5)  \
# 0  [{'text': 'billing errors, which include inacc...                    4
# 1  [{'text': 'closure of all current accounts and...                    4
# 2  [{'text': 'y other bank as well, which has giv...                    3
# 3  [{'text': 'issues or chargebacks.', 'metadata'...                    2
# 4  [{'text': 'card companies and the credit burea...                    3
#
#                                  Comments / Analysis
# 0  Answer accurately summarizes recurring billing...
# 1  Correctly identifies companies involved in acc...
# 2  Relevant context retrieved, but answer is base...
# 3  System correctly avoided hallucination, but re...
# 4  Identifies a major company, but aggregation ac...
